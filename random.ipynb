# %% [markdown]
# # Random Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
df = pd.DataFrame(np.random.rand(900,250) * 10000)

# Split dataframe into 3 classes with 300 samples each.
df['class'] = 0
df.loc[300:599, 'class'] = 1
df.loc[600:, 'class'] = 2

df.head()
# Out:
#              0            1            2            3            4  \
# 0  2614.021644  5733.395529  3361.587429  5937.090209  6175.866852
# 1  1846.437359   484.988864  7231.988872  3942.176888  2208.338618
# 2  6591.241888  3420.403042    55.277945  2320.364678  2693.388956
# 3  4558.708406  1419.835966  2824.954434  2711.244119  7045.395661
# 4  5873.112937  6519.178366  4369.293154  6413.236727  4336.704643
#
#              5            6            7            8            9  ...  \
# 0  8196.879360  6148.982134  7047.927674  4737.911870  3392.557473  ...
# 1  3003.176078  7271.081032  4308.518274  4516.431354  5055.483404  ...
# 2  1764.870428  2758.562720  4118.874773  7113.930160  1124.651957  ...
# 3  4752.148428  4729.237666  4119.968215    67.263700  5391.525898  ...
# 4  2787.050656   293.461944  4061.451554  1006.839177  2594.286950  ...
#
#            241          242          243          244          245  \
# ...

# %% [markdown]
# ## 5 Features Random Sample

# %%
# Five Features
X = df.iloc[:, :5]
y = df['class']

# %% [markdown]
# ### PCA

# %%
X_transformed = PCA().fit_transform(X)

# %%
# PCA Scatter Plot
plt.figure(figsize=[8,6])
p = sns.scatterplot(
    x=X_transformed[:,0],
    y=X_transformed[:,1],
    hue=y,
    palette=sns.color_palette("hls", 3),
    )

p.set(title="Random 5 Features PCA", xlabel="PC1", ylabel="PC2")
plt.show()

# %% [markdown]
# ### LDA

# %%
X_transformed = LinearDiscriminantAnalysis().fit_transform(X, y)

# %%
# LDA Scatter Plot
plt.figure(figsize=[8,6])
p = sns.scatterplot(
    x=X_transformed[:,0],
    y=X_transformed[:,1],
    hue=y,
    palette=sns.color_palette("hls", 3),
    )

p.set(title="Random 5 Features LDA", xlabel="LD1", ylabel="LD2")
plt.show()

# %% [markdown]
# ## 250 Features Random Sample

# %%
X = df.iloc[:, :250]
y = df['class']

# %% [markdown]
# ### PCA

# %%
X_transformed = PCA().fit_transform(X)

# %%
# PCA Scatter Plot
plt.figure(figsize=[8,6])
p = sns.scatterplot(
    x=X_transformed[:,0],
    y=X_transformed[:,1],
    hue=y,
    palette=sns.color_palette("hls", 3),
    )

p.set(title="Random 250 Features PCA", xlabel="PC1", ylabel="PC2")
plt.show()

# %% [markdown]
# ### LDA

# %%
X_transformed = LinearDiscriminantAnalysis().fit_transform(X, y)

# %%
# LDA Scatter Plot
plt.figure(figsize=[8,6])
p = sns.scatterplot(
    x=X_transformed[:,0],
    y=X_transformed[:,1],
    hue=y,
    palette=sns.color_palette("hls", 3),
    )

p.set(title="Random 250 Features LDA", xlabel="LD1", ylabel="LD2")
plt.show()
